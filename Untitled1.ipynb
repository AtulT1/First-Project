# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
df=pd.read_csv("BRENT.csv",parse_dates=True,squeeze=True)
df.head(10)
# Out:
#                   Gmt time   Open   High    Low  Close  Volume
# 0  01.01.2015 00:00:00.000  56.83  56.83  56.83  56.83     0.0
# 1  01.01.2015 01:00:00.000  56.83  56.83  56.83  56.83     0.0
# 2  01.01.2015 02:00:00.000  56.83  56.83  56.83  56.83     0.0
# 3  01.01.2015 03:00:00.000  56.83  56.83  56.83  56.83     0.0
# 4  01.01.2015 04:00:00.000  56.83  56.83  56.83  56.83     0.0
# 5  01.01.2015 05:00:00.000  56.83  56.83  56.83  56.83     0.0
# 6  01.01.2015 06:00:00.000  56.83  56.83  56.83  56.83     0.0
# 7  01.01.2015 07:00:00.000  56.83  56.83  56.83  56.83     0.0
# 8  01.01.2015 08:00:00.000  56.83  56.83  56.83  56.83     0.0
# 9  01.01.2015 09:00:00.000  56.83  56.83  56.83  56.83     0.0

# %%
#df.set_index('Gmt time',drop=False,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21385 entries, 0 to 21384
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Gmt time  21385 non-null  object
#  1   Open      21385 non-null  float64
#  2   High      21385 non-null  float64
#  3   Low       21385 non-null  float64
#  4   Close     21385 non-null  float64
#  5   Volume    21385 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 1002.5+ KB

# %%
df.Close.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df.Open.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df.drop('Volume',axis=1,inplace=True)

# %%
df['Gmt time']=pd.to_datetime(df['Gmt time'],format='%d.%m.%Y %H:%M:%S.%f')

# %%
type(df['Gmt time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
groups=df.groupby(pd.Grouper(key="Gmt time",freq='1M')).sum()

# %%
groups.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Gmt time'>

# %%
df.plot(x=df['Gmt time'],y=['Open'],kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_13114/1959268730.py in <module>
# ----> 1 df.plot(x=df['Gmt time'],y=['Open'],kind='bar')
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
# ...
